# %% [markdown]
# ## 파일 입출력
#
#
# - 파이썬 표준 함수(내장함수)에는 파일과 관련된 처리를 하는 함수가 기본으로 제공된다.
# - 파일은 텍스트 파일과 바이너리 파일로 나뉜다.
# - 파일을 열때 open( )함수를 사용한다.
# - 파일 입출력 순서
#
#  ① 어플리케이션이 운영체제에게 파일 처리를 API 함수를 통해 의뢰하면, 운영체제가
#    요청한 업무를 수행해 주고 그 결과를 어플리케이션에게 돌려줌.
#
#  ② 어플리케이션이 파일 처리 업무를 의뢰하는 과정과 각 과정에서 사용되는 파이썬
#     함수
#
#
#
#
#
#
# | 단계 | 처리 흐름 | 매칭 소스 코드 | 세부 설명 |
# |---|---|---|---|
# | ① | 파일 열기 | file = open() | open() 내장함수로 파일을 연다. |
# | ② | 파일 읽기/쓰기 | file.read() / file.write() | 얻어진 파일 객체에서 데이터를 읽고 쓴다.(read,write) |
# | ③ | 파일 닫기 | file.close() | close() 함수로 객체의 사용을 종료한다. |
#
#
#
#
# 파일객체 = open('파일경로', '파일열기모드')
#
#
# | 파일 열기 모드 | 기능 |
# |---|---|
# |w:쓰기모드|파일에 내용을 쓸|
# |a:추가모드 | 파일에 내용을 추가할때 사용 |
#
#
#
#
# 파일 읽기/쓰기 함수
#
#
# | 구분 | 함수(메서드)명 | 반환 및 특징 |
# | :---: | :--- | :--- |
# | **읽기 (Read)** | `read()` | 파일 전체 내용을 하나의 문자열로 반환 |
# | **읽기 (Read)** | `readline()` | 파일의 현재 위치에서 딱 한 줄만 반환 |
# | **읽기 (Read)** | `readlines()` | 모든 줄을 읽어 문자열 리스트로 반환 |
# | **쓰기 (Write)** | `write()` | 문자열 하나를 파일에 기록 |
# | **쓰기 (Write)** | `writelines()` | 문자열 리스트/튜플을 한 번에 기록 |

# %%
#폴더는 만들어져 있어야 한다
# %mkdir source

# %%
fwrite = open('source_skn/sample.txt', 'w') #파일을 쓰기로 오픈한다(업데이트)
fwrite.write('test data')
fwrite.close()

# %%
# %echo source_skn/sample.txt
# Out:
# source_skn/sample.txt

# %%
fwrite = open('source_skn/sample.txt', 'w')  #내용 사라지고 새로운 내용으로 바뀜
for i in range(1,6):
    data = '{}번째 줄입니다.'.format(i)
    fwrite.write(data)
fwrite.close() #파일 닫기

# %%
fread = open('source_skn/sample.txt', 'r' ) #파일을 읽기로 오픈한다
line = fread.read() #read()는 파일의 모든 데이터를 읽어온다
print(line)
print(type(line))  #<class 'str'>
fread.close()  #파일 닫기
# Out:
# 1번째 줄입니다.2번째 줄입니다.3번째 줄입니다.4번째 줄입니다.5번째 줄입니다.
# <class 'str'>

# %%
fwrite = open('source_skn/sample.txt', 'w' )  #쓰기로 오픈 (업데이트) 새로써진 내용만 파일에 있음

for i in range(1, 6):
    data = '{}번째 줄입니다.'.format(i)
    fwrite.write(data + "\n")
fwrite.close()

# %%
fread = open('source_skn/sample.txt', 'r')
line = fread.read()  #모든 내용을 읽어옴
print(line)
print(type(line))  #<class(str)>
# Out:
# 1번째 줄입니다.
# 2번째 줄입니다.
# 3번째 줄입니다.
# 4번째 줄입니다.
# 5번째 줄입니다.
#
# <class 'str'>

# %%
fread = open('source_skn/sample.txt', 'r' ) #파일을 읽기로 오픈한다

while True:
    line = fread.readline()  #readline은 한 줄씩 읽어온다.
    print(line)
    if not line: #파일에서 더 이상 읽어올 내용이 없으면
        break             #현재 수행중인 반복문 빠져나옴

fread.close()             #파일 닫기
# Out:
# 1번째 줄입니다.
#
# 2번째 줄입니다.
#
# 3번째 줄입니다.
#
# 4번째 줄입니다.
#
# 5번째 줄입니다.

# %%
fread = open('source_skn/sample.txt', 'r' ) #파일을 읽기로 오픈한다

while True:
    line = fread.readline()  #readline은 한 줄씩 읽어온다.
    
    if not line: #파일에서 더 이상 읽어올 내용이 없으면
        break             #현재 수행중인 반복문 빠져나옴
    print(line, end='')

fread.close()             #파일 닫기
# Out:
# 1번째 줄입니다.
# 2번째 줄입니다.
# 3번째 줄입니다.
# 4번째 줄입니다.
# 5번째 줄입니다.

# %%
fread = open('source_skn/sample.txt', 'r' ) #파일을 읽기로 오픈한다
line = fread.readlines()   #readlines()는 파일에서 한 라인씩 읽어와서 list에 저장한 후 리턴한다.
print(type(line))
print(line)  # ['1번째 줄입니다.\n', '2번째 줄입니다.\n', '3번째 줄입니다.\n', '4번째 줄입니다.\n', '5번째 줄입니다.\n']
fread.close()

for data in line:
    print(data, end='')
# Out:
# <class 'list'>
# ['1번째 줄입니다.\n', '2번째 줄입니다.\n', '3번째 줄입니다.\n', '4번째 줄입니다.\n', '5번째 줄입니다.\n']
# 1번째 줄입니다.
# 2번째 줄입니다.
# 3번째 줄입니다.
# 4번째 줄입니다.
# 5번째 줄입니다.

# %% [markdown]
# ### with문과 함께 사용
# - with문과 함께 파일을 사용하면 읽기, 쓰기 할 때 close()를 안해도 된다.

# %%
with open('source_skn/sample.txt', 'a') as f:   #'a' : append 기존 놔두고 추가함  #파일에 새로운 내용을 추가한다.
    for i in range(6, 11):
        data = '{}번째 줄입니다.'.format(i)
        f.write(data + '\n')
f.close()

# %%
with open('source_skn/sample.txt') as f:
    while True:
        line = f.readline()
        if not line :
            break
        print(line, end='')
# Out:
# 1번째 줄입니다.
# 2번째 줄입니다.
# 3번째 줄입니다.
# 4번째 줄입니다.
# 5번째 줄입니다.
# 6번째 줄입니다.
# 7번째 줄입니다.
# 8번째 줄입니다.
# 9번째 줄입니다.
# 10번째 줄입니다.

# %%
with open('source_skn/test.txt', 'w') as f:
    f.writelines(['apple', 'banana', 'lemon'])  # / lines는 반복객체 가능(튜플, 리스트, dict)
    #f.write(['apple', 'banana', 'lemon'])  # wirte()에 리스트 넣으면 오류남 str만 가능함

# %%
with open('source_skn/test.txt', 'r') as f:
    print(f.readline())  # str    # applebananalemon
    #print(f.readlines())   #list   # ['applebananalemon']
# Out:
# applebananalemon

# %%
with open('source_skn/multi.txt', 'w') as f:
    f.writelines(['apple', 10, True])  #TypeError: write() argument must be str, not int
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 2
#       1 with open('source_skn/multi.txt', 'w') as f:
# ----> 2     f.writelines(['apple', 10, True])
#
# TypeError: write() argument must be str, not int

# %% [markdown]
# ## 주요 입출력(직렬화/데이터 저장) 모듈
# 직렬화(Serialization)란?
# - 파이썬의 객체(리스트, 딕셔너리, 클래스 등)를 파일로 저장하거나     네트워크로 전송할 수 있는 바이트/텍스트 형태로 변환하는 작업입니다.
# - 입출력 모듈 종류
# ①pickle: 텍스트 상태의 데이터가 아닌 파이썬 객체 자체를 파일로 저장하는 모듈
# ②json : 타 언어 호환성이 가장 뛰어난 텍스트 기반 모듈
# ③csv : 엑셀과 연동되는 표 형태 데이터 전용 모듈
# ④marshal : 파이썬 내부 바이트코드를 위한 고속 모듈
# ⑤shelve : 파일 자체를 딕셔너리처럼 쓰는 영구 저장소 모듈
# ⑥configparser : 설정 파일(INI)을 관리하는 전용 모듈
#
#
#
#
#
#
# | 모듈명 | 데이터 형태 | 타 언어 호환 | 보안성 | 주요 용도 |
# | :---: | :---: | :---: | :---: | :--- |
# | **pickle** | 바이너리 | 불가능 (파이썬 전용) | ⚠️ 취약 (경고) | 파이썬 복잡한 객체 완벽 저장 |
# | **json** | 텍스트 (문자열) | **우수 (글로벌 표준)** | 안전함 | 웹 API 통신, 일반 데이터 저장 |
# | **shelve** | 바이너리 | 불가능 (파이썬 전용) | ⚠️ 취약 (경고) | 대용량 key-value 로컬 데이터베이스 |
# | **csv** | 텍스트 (문자열) | **우수 (엑셀 연동)** | 안전함 | 표 형태 데이터, 데이터베이스 내보내기 |

# %% [markdown]
# =============
# ### pickle 모듈이란?
# - 파이썬 객체 구조를 그대로 바이트 스트림으로 변환(직렬화)하고, 이를 다시 파이썬 객체로 복원(역직렬화)하는 파이썬 고유의 표준 모듈
#
#
# - 핵심 함수
#  ①pickle.dump(obj, file): 객체를 바이너리 파일에 저장
#  ②pickle.load(file): 바이너리 파일로 부터 객체를 복원
#
#
# - ⚠치명적인 보안 경고 (중요)
# ①pickle은 신뢰할 수 없는 데이터(인터넷에서 다운로드한 파일 등)를 역직렬화할 때    악성 코드가 자동으로 실행될 수 있는 심각한 보안 취약점이 있다.
# ②따라서 외부 통신용 데이터 저장에는 절대로 사용을 지양해야 한다.

# %%
import pickle

# %%
with open('source_skn/sample.txt', 'wb') as f:  #byte로 저장 'wb'
    pickle.dump(['apple', 'banana', 'lemon'], f) # dump(저장할 데이터, 파일])

# %%
with open('source_skn/sample.txt', 'rb') as f: #byte니까 'rb'
    print(pickle.load(f))      #['apple', 'banana', 'lemon']
# Out:
# ['apple', 'banana', 'lemon']
